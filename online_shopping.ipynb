# %% [markdown]
# <a href="https://colab.research.google.com/github/manojkumar88838/onlline-shopping-cart-system/blob/main/online_shopping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cart = {}
# Example of the intended structure (uncomment to add items):
# cart = {
#     "Laptop": {"price": 1200.00, "quantity": 1},
#     "Mouse": {"price": 25.00, "quantity": 2}
# }
